# %%
import pandas as pd
import numpy as np
import s3fs
import boto3
import io

# %%
def read_parquet_to_pandas(bucket, prefix, profile=None): 
    fs = s3fs.S3FileSystem(profile=profile)
    parquet_files = fs.ls(f"{bucket}/{prefix}")
    
    session = boto3.Session(profile_name=profile) if profile else boto3.Session()
    s3 = session.client('s3')
    
    all_chunks = []

    parquet_files = ['s3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part0_part0.parquet', 
                     's3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part1_part0.parquet', 
                     's3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part10_part0.parquet', 
                     's3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part11_part0.parquet', 
                     's3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part12_part0.parquet']

    for pq_file in parquet_files[:5]: 
        print(f"🔍 Processing: s3://{pq_file}")

        with fs.open(pq_file, 'rb') as f: 
            df = pd.read_parquet(f, engine='pyarrow')
            all_chunks.append(df)
    
    return pd.concat(all_chunks, ignore_index=True)

# %%
df = read_parquet_to_pandas('mortgage-data-clean', 'hmda/2022', 'AdministratorAccess-769392325318')
# Out:
# 🔍 Processing: s3://s3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part0_part0.parquet
# 🔍 Processing: s3://s3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part1_part0.parquet
# 🔍 Processing: s3://s3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part10_part0.parquet
# 🔍 Processing: s3://s3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part11_part0.parquet
# 🔍 Processing: s3://s3://mortgage-data-clean/hmda/2022/public_lar2023_public_lar_csv_part12_part0.parquet

# %%
df.head()
# Out:
#    activity_year                   lei  derived_msa_md state_code  \
# 0           2023  549300JOT0D4J0SZIK67           29460         FL
# 1           2023  549300JOT0D4J0SZIK67           29820         NV
# 2           2023  549300JOT0D4J0SZIK67           49420         WA
# 3           2023  549300JOT0D4J0SZIK67           28140         KS
# 4           2023  549300JOT0D4J0SZIK67           28420         WA
#
#    county_code  census_tract conforming_loan_limit derived_loan_product_type  \
# 0      12105.0  1.210501e+10                     C             VA:First Lien
# 1      32003.0  3.200300e+10                     C            FHA:First Lien
# 2      53077.0  5.307700e+10                     C             VA:First Lien
# 3      20091.0  2.009105e+10                     C            FHA:First Lien
# 4      53005.0  5.300501e+10                     C   Conventional:First Lien
#
#               derived_dwelling_category        derived_ethnicity  ...  \
# 0  Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
# 1  Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
# 2  Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
# 3  Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
# 4  Single Family (1-4 Units):Site-Built  Ethnicity Not Available  ...
#
#   denial_reason_2 denial_reason_3  denial_reason_4  tract_population  \
# 0             NaN             NaN              NaN              2570
# 1             NaN             NaN              NaN              7043
# 2             NaN             NaN              NaN              3044
# 3             NaN             NaN              NaN              4079
# 4             NaN             NaN              NaN              9675
#
#    tract_minority_population_percent  ffiec_msa_md_median_family_income  \
# 0                              43.15                              74300
# 1                              56.92                              83900
# 2                              19.02                              76600
# 3                              10.17                             104400
# 4                              26.74                             101700
#
#    tract_to_msa_income_percentage  tract_owner_occupied_units  \
# 0                          111.11                         441
# 1                          109.65                        1383
# 2                          131.97                        1031
# 3                          166.18                        1240
# 4                          128.98                        2474
#
#    tract_one_to_four_family_homes  tract_median_age_of_housing_units
# 0                             716                                 25
# 1                            2057                                 15
# 2                            1288                                 35
# 3                            1341                                 37
# 4                            2688                                 15
#
# [5 rows x 99 columns]

# %%
fs = s3fs.S3FileSystem(profile='AdministratorAccess-769392325318')  # or None for default profile

with fs.open('mortgage-data-refined/dycu_outputs/HMDA_2022_CTData.xls', 'rb') as f:
    target_df = pd.read_excel(f)
    target_df.head()

# %%
target_df.head()
# Out:
#    census_tract  TotalOriginations  WhiteNonHispanicOriginations  \
# 0   55079000101                 29                             3
# 1   55079187000                 27                            16
# 2   55079018600                 15                             0
# 3   55079003500                 37                             6
# 4   55079017900                 30                            23
#
#    BlackOriginations  LatinxOriginations  AAPIOriginations  Applications  \
# 0                 10                   2                 3            52
# 1                  3                   3                 1            42
# 2                  1                  11                 1            22
# 3                 21                   5                 2            61
# 4                  0                   2                 1            49
#
#    Denials  Fallout  OriginationRate  DenialRate  FalloutRate
# 0        6       11         0.557692    0.115385     0.211538
# 1        1        7         0.642857    0.023810     0.166667
# 2        1        4         0.681818    0.045455     0.181818
# 3        7        8         0.606557    0.114754     0.131148
# 4        1       11         0.612245    0.020408     0.224490
